# %%
# Set own library path
import sys
sys.path.append('/Users/guillemmirabentrubinat/Library/CloudStorage/OneDrive-Personal/BSE/CDS Computing for Data Science/Problem Sets/hw3/Computing-for-DS-HW2/GMR_lib1')

# Import Libraries

import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from GMR_lib1.module1 import nan_remover

# Import Dataset

data = pd.read_csv('sample_diabetes_mellitus_data.csv')
display(data)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /Users/guillemmirabentrubinat/Library/CloudStorage/OneDrive-Personal/BSE/CDS Computing for Data Science/Problem Sets/hw3/Computing-for-DS-HW2/GMR_analysis.ipynb Cell 1 line 1
#      <a href='vscode-notebook-cell:/Users/guillemmirabentrubinat/Library/CloudStorage/OneDrive-Personal/BSE/CDS%20Computing%20for%20Data%20Science/Problem%20Sets/hw3/Computing-for-DS-HW2/GMR_analysis.ipynb#W0sZmlsZQ%3D%3D?line=9'>10</a> from sklearn.model_selection import train_test_split
#      <a href='vscode-notebook-cell:/Users/guillemmirabentrubinat/Library/CloudStorage/OneDrive-Personal/BSE/CDS%20Computing%20for%20Data%20Science/Problem%20Sets/hw3/Computing-for-DS-HW2/GMR_analysis.ipynb#W0sZmlsZQ%3D%3D?line=10'>11</a> from sklearn.metrics import roc_auc_score
# ...

# %%
# Cleaning the data using the functions from the library
data_safecopy = data

gmr.nan_remover(data, ['age', 'gender', 'ethnicity'])
display(data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/guillemmirabentrubinat/Library/CloudStorage/OneDrive-Personal/BSE/CDS Computing for Data Science/Problem Sets/hw3/Computing-for-DS-HW2/GMR_analysis.ipynb Cell 2 line 4
#       <a href='vscode-notebook-cell:/Users/guillemmirabentrubinat/Library/CloudStorage/OneDrive-Personal/BSE/CDS%20Computing%20for%20Data%20Science/Problem%20Sets/hw3/Computing-for-DS-HW2/GMR_analysis.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> # Cleaning the data using the functions from the library
#       <a href='vscode-notebook-cell:/Users/guillemmirabentrubinat/Library/CloudStorage/OneDrive-Personal/BSE/CDS%20Computing%20for%20Data%20Science/Problem%20Sets/hw3/Computing-for-DS-HW2/GMR_analysis.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> data_safecopy = data
# ...

# %%
# Split the data between train and test

X_train, X_test, y_train, y_test = train_test_split(
    data.drop('diabetes_mellitus', axis=1),
    data['diabetes_mellitus'],
    test_size=0.2,
    random_state=42
    )

#X_train.head()
#X_test.head()
#print(len(y_train))
#print(y_test)
# Out:
#       Unnamed: 0  encounter_id  hospital_id   age        bmi  \
# 6252        6252        275141           81  66.0  34.852863
# 4684        4684        269942          118   NaN  18.593750
# 1731        1731        183562          118  83.0  28.215375
# 4742        4742        244929          118  64.0  21.575502
# 4521        4521        193781          118  21.0  34.560280
#
#       elective_surgery         ethnicity gender  height hospital_admit_source  \
# 6252                 0         Caucasian      M   180.3  Emergency Department
# 4684                 0         Caucasian      F   160.0                   NaN
# 1731                 0         Caucasian      F   154.9        Other Hospital
# 4742                 1         Caucasian      F   170.2  Emergency Department
# 4521                 1  African American      F   162.0        Operating Room
#
#       ... urineoutput_apache  ventilated_apache wbc_apache aids  cirrhosis  \
# ...
